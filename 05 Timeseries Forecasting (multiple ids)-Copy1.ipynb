# %% [markdown]
# # Timeseries Forecasting

# %% [markdown]
# This notebook explains how to use `tsfresh` in time series foreacasting.
# Make sure you also read through the [documentation](https://tsfresh.readthedocs.io/en/latest/text/forecasting.html) to learn more on this feature.
#
# It is basically a copy of the other time series forecasting notebook, but this time using more than one
# stock.
# This is conceptionally not much different, but the pandas multi-index magic is a bit advanced :-)
#
# We will use the Google, Facebook and Alphabet stock.
# Please find all documentation in the other notebook.

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pylab as plt

from tsfresh import extract_features, select_features
from tsfresh.utilities.dataframe_functions import roll_time_series, make_forecasting_frame
from tsfresh.utilities.dataframe_functions import impute

try:
    import pandas_datareader.data as web
except ImportError:
    print("You need to install the pandas_datareader. Run pip install pandas_datareader.")

from sklearn.ensemble import AdaBoostRegressor

# %% [markdown]
# ## Reading the data

# %%
df_melted = pd.read_excel("train.xlsx")

# %%
df_melted.head()
# Out:
#    Unnamed: 0  Time     Symbols   High
# 0           0     0  Sensor1 c1 -50.85
# 1           1     1  Sensor1 c1 -49.40
# 2           2     2  Sensor1 c1 -40.04
# 3           3     3  Sensor1 c1 -47.14
# 4           4     4  Sensor1 c1 -33.58

# %% [markdown]
# ## Create training data sample

# %%
df_rolled = roll_time_series(df_melted, column_id="Symbols", column_sort="Time",
                             max_timeshift=999, min_timeshift=999)
# Out:
# Rolling: 100%|██████████| 30/30 [00:01<00:00, 20.39it/s]

# %%
df_rolled.tail()
# Out:
#        Unnamed: 0  Time     Symbols    High                           id
# 31995        8995   995  Sensor9 c1  643.57  id=Sensor9 c1,timeshift=999
# 31996        8996   996  Sensor9 c1  645.60  id=Sensor9 c1,timeshift=999
# 31997        8997   997  Sensor9 c1  653.53  id=Sensor9 c1,timeshift=999
# 31998        8998   998  Sensor9 c1  641.36  id=Sensor9 c1,timeshift=999
# 31999        8999   999  Sensor9 c1  642.65  id=Sensor9 c1,timeshift=999

# %% [markdown]
# ## Extract Features

# %%
X = extract_features(df_rolled.drop("Symbols", axis=1), 
                     column_id="id", column_sort="Time", column_value="High", 
                     impute_function=impute, show_warnings=False)
# Out:
# Feature Extraction: 100%|██████████| 16/16 [00:08<00:00,  1.83it/s]

# %%
X.head()
# Out:
# variable                       High__abs_energy  \
# id
# id=Sensor1  c2,timeshift=999       1.975064e+09
# id=Sensor1 c1,timeshift=999        1.094491e+09
# id=Sensor10  c2,timeshift=999      7.452665e+09
# id=Sensor10 c1,timeshift=999       9.731286e+10
# id=Sensor11  c2,timeshift=999      1.617532e+10
#
# variable                       High__absolute_sum_of_changes  \
# id
# id=Sensor1  c2,timeshift=999                         6549.12
# id=Sensor1 c1,timeshift=999                          6401.74
# id=Sensor10  c2,timeshift=999                       10079.03
# id=Sensor10 c1,timeshift=999                        54768.88
# id=Sensor11  c2,timeshift=999                       12561.72
#
# variable                       High__agg_autocorrelation__f_agg_"mean"__maxlag_40  \
# id
# id=Sensor1  c2,timeshift=999                                            0.978032
# id=Sensor1 c1,timeshift=999                                             0.977813
# id=Sensor10  c2,timeshift=999                                           0.011889
# id=Sensor10 c1,timeshift=999                                            0.760298
# id=Sensor11  c2,timeshift=999                                           0.777630
#
# variable                       High__agg_autocorrelation__f_agg_"median"__maxlag_40  \
# id
# id=Sensor1  c2,timeshift=999                                            0.978772
# id=Sensor1 c1,timeshift=999                                             0.978643
# id=Sensor10  c2,timeshift=999                                           0.007736
# id=Sensor10 c1,timeshift=999                                            0.752790
# id=Sensor11  c2,timeshift=999                                           0.777902
#
# variable                       High__agg_autocorrelation__f_agg_"var"__maxlag_40  \
# id
# id=Sensor1  c2,timeshift=999                                            0.000176
# id=Sensor1 c1,timeshift=999                                             0.000180
# id=Sensor10  c2,timeshift=999                                           0.000767
# id=Sensor10 c1,timeshift=999                                            0.016021
# id=Sensor11  c2,timeshift=999                                           0.000968
#
# variable                       High__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"max"  \
# id
# id=Sensor1  c2,timeshift=999                                         -308.200242
# id=Sensor1 c1,timeshift=999                                          -220.713699
# id=Sensor10  c2,timeshift=999                                        2743.112499
# id=Sensor10 c1,timeshift=999                                        14378.940923
# id=Sensor11  c2,timeshift=999                                        4074.369594
#
# variable                       High__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"mean"  \
# id
# id=Sensor1  c2,timeshift=999                                         -322.104256
# id=Sensor1 c1,timeshift=999                                          -231.722674
# id=Sensor10  c2,timeshift=999                                        2730.069070
# id=Sensor10 c1,timeshift=999                                        13566.577716
# id=Sensor11  c2,timeshift=999                                        4057.496626
#
# variable                       High__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"min"  \
# id
# id=Sensor1  c2,timeshift=999                                         -335.119071
# id=Sensor1 c1,timeshift=999                                          -241.575131
# id=Sensor10  c2,timeshift=999                                        2716.945297
# id=Sensor10 c1,timeshift=999                                        12785.301960
# id=Sensor11  c2,timeshift=999                                        4039.931091
#
# variable                       High__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"var"  \
# id
# id=Sensor1  c2,timeshift=999                                           90.549462
# id=Sensor1 c1,timeshift=999                                            53.074467
# id=Sensor10  c2,timeshift=999                                          68.797627
# id=Sensor10 c1,timeshift=999                                       545511.901531
# id=Sensor11  c2,timeshift=999                                         105.726122
#
# variable                       High__agg_linear_trend__attr_"intercept"__chunk_len_50__f_agg_"max"  \
# id
# id=Sensor1  c2,timeshift=999                                         -201.750000
# id=Sensor1 c1,timeshift=999                                          -140.857571
# id=Sensor10  c2,timeshift=999                                        2748.965857
# id=Sensor10 c1,timeshift=999                                        17742.654143
# id=Sensor11  c2,timeshift=999                                        4080.022714
#
# variable                       ...  \
# id                             ...
# id=Sensor1  c2,timeshift=999   ...
# id=Sensor1 c1,timeshift=999    ...
# id=Sensor10  c2,timeshift=999  ...
# id=Sensor10 c1,timeshift=999   ...
# id=Sensor11  c2,timeshift=999  ...
#
# variable                       High__symmetry_looking__r_0.9500000000000001  \
# id
# id=Sensor1  c2,timeshift=999                                            1.0
# id=Sensor1 c1,timeshift=999                                             1.0
# id=Sensor10  c2,timeshift=999                                           1.0
# id=Sensor10 c1,timeshift=999                                            1.0
# id=Sensor11  c2,timeshift=999                                           1.0
#
# variable                       High__time_reversal_asymmetry_statistic__lag_1  \
# id
# id=Sensor1  c2,timeshift=999                                     1.650319e+07
# id=Sensor1 c1,timeshift=999                                      6.568537e+06
# id=Sensor10  c2,timeshift=999                                    2.216231e+05
# id=Sensor10 c1,timeshift=999                                    -1.706120e+11
# id=Sensor11  c2,timeshift=999                                   -6.576646e+06
#
# variable                       High__time_reversal_asymmetry_statistic__lag_2  \
# id
# id=Sensor1  c2,timeshift=999                                     3.310424e+07
# id=Sensor1 c1,timeshift=999                                      1.316982e+07
# id=Sensor10  c2,timeshift=999                                    4.976937e+05
# id=Sensor10 c1,timeshift=999                                    -3.292963e+11
# id=Sensor11  c2,timeshift=999                                   -1.233438e+07
#
# variable                       High__time_reversal_asymmetry_statistic__lag_3  \
# id
# id=Sensor1  c2,timeshift=999                                     4.962891e+07
# id=Sensor1 c1,timeshift=999                                      1.980420e+07
# id=Sensor10  c2,timeshift=999                                    4.550993e+05
# id=Sensor10 c1,timeshift=999                                    -4.777239e+11
# id=Sensor11  c2,timeshift=999                                   -1.710828e+07
#
# variable                       High__value_count__value_-1  \
# id
# id=Sensor1  c2,timeshift=999                           0.0
# id=Sensor1 c1,timeshift=999                            0.0
# id=Sensor10  c2,timeshift=999                          0.0
# id=Sensor10 c1,timeshift=999                           0.0
# id=Sensor11  c2,timeshift=999                          0.0
#
# variable                       High__value_count__value_0  \
# id
# id=Sensor1  c2,timeshift=999                          0.0
# id=Sensor1 c1,timeshift=999                           1.0
# id=Sensor10  c2,timeshift=999                         0.0
# id=Sensor10 c1,timeshift=999                          0.0
# id=Sensor11  c2,timeshift=999                         0.0
#
# variable                       High__value_count__value_1  High__variance  \
# id
# id=Sensor1  c2,timeshift=999                          0.0    7.243809e+05
# id=Sensor1 c1,timeshift=999                           0.0    3.965150e+05
# id=Sensor10  c2,timeshift=999                         0.0    7.891655e+01
# id=Sensor10 c1,timeshift=999                          0.0    7.712715e+07
# id=Sensor11  c2,timeshift=999                         0.0    7.526326e+02
#
# variable                       High__variance_larger_than_standard_deviation  \
# id
# id=Sensor1  c2,timeshift=999                                             1.0
# id=Sensor1 c1,timeshift=999                                              1.0
# id=Sensor10  c2,timeshift=999                                            1.0
# id=Sensor10 c1,timeshift=999                                             1.0
# id=Sensor11  c2,timeshift=999                                            1.0
#
# variable                       High__variation_coefficient
# id
# id=Sensor1  c2,timeshift=999                      0.761044
# id=Sensor1 c1,timeshift=999                       0.753719
# id=Sensor10  c2,timeshift=999                     0.003254
# id=Sensor10 c1,timeshift=999                      1.954707
# id=Sensor11  c2,timeshift=999                     0.006821
#
# [5 rows x 763 columns]

# %%
X.to_excel("latest.xlsx")

# %%
pwd
# Out:
# '/home/nitin/Desktop/shanur/gas'

# %% [markdown]
# We make the data a bit easier to work with by giving them a multi-index instead ot the tuple index:
